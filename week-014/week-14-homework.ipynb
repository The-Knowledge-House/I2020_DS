# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1 >Week 14 Homework</h1>
# </div>

# %%
# imports
import numpy as np

# %% [markdown]
# # __Note: If you do the following  with numpy arrays, the asserts will need adjusting.__

# %% [markdown]
# ## Exercise 1
# Given the array `nums` consisting of `2n` elements in the form `[x1,x2,...,xn,y1,y2,...,yn]`.
#
# Return the array in the form `[x1,y1,x2,y2,...,xn,yn]`.
#
# `Example 1:`
#
# __Input__: `nums = [2,5,1,3,4,7]`, `n = 3`
# __Output__: `[2,3,5,4,1,7]`
# __Explanation__: Since x<sub>1</sub>=2, x<sub>2</sub>=5, x<sub>3</sub>=1, y<sub>1</sub>=3, y<sub>2</sub>=4, y<sub>3</sub>=7 then the answer is `[2,3,5,4,1,7]`.
#
# `Example 2:`
#
# __Input__: `nums = [1,2,3,4,4,3,2,1], n = 4`
# __Output__: `[1,4,2,3,3,2,4,1]`
#
# `Example 3:`
#
# __Input__: `nums = [1,1,2,2], n = 2`
# __Output__: `[1,2,1,2]`
#
# __`Bonus: Try to do this with numpy arrays.`__

# %%
def ex1(nums):
    pass

try:
    assert(ex1([2,5,1,3,4,7]) == [2,3,5,4,1,7])
    assert(ex1([1,2,3,4,4,3,2,1]) == [1,4,2,3,3,2,4,1])
    assert(ex1([1,1,2,2]) == [1,2,1,2])
    print("solution is correct")
except AssertionError:
    print("solution is incorrect")

# %% [markdown]
# ## Exercise 2
#
# Given an integer `n` and an integer `start`.
#
# Define an array `nums` where `nums[i] = start + 2*i` (0-indexed) and `n == nums.length`.
#
# Return the bitwise XOR of all elements of `nums`.
#
# Note: Bitwise XOR in python is the `^` operator
#
#
# __`Example 1:`__
#
# __Input__: `n = 5`, `start = 0`
# __Output__: `8`
# __Explanation__: Array nums is equal to `[0, 2, 4, 6, 8]` where `(0 ^ 2 ^ 4 ^ 6 ^ 8) = 8`.
# Where "^" corresponds to bitwise XOR operator
#
# __`Example 2:`__
#
# __Input__: `n = 4, start = 3`
# __Output__: `8`
# __Explanation__: Array nums is equal to `[3,5,7,9]` where `(3 ^ 5 ^ 7 ^ 9) = 8`.
#
# __`Example 3:`__
#
# __Input__: `n = 1, start = 7`
# __Output__: `7`
#
# __`Example 4:`__
#
# __Input__: `n = 10, start = 5`
# __Output__: `2`
#
#
# __`Bonus: Try to do this with numpy arrays.`__

# %%
def ex2(n,start):
    pass

try:
    assert(ex2(5,0) == 8)
    assert(ex2(4,3) == 8)
    assert(ex2(1,7) == 7)
    assert(ex2(10,5) == 2)
    print("solution is correct")
except AssertionError:
    print("solution is incorrect")

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1 >Reading for next week</h1>
# </div>

# %% [markdown]
# ### Required
#
# __Introducing Data Science__ - https://www.programmer-books.com/wp-content/uploads/2018/07/Introducing-Data-Science-Big-Data-Machine-Learning-and-more-using-Python-tools-2016.pdf
# (Chapter 1 and 2)
#
# ### Worth Checking out for next week:
#
# __An Introduction to Statistical Learning__ - https://statlearning.com/ISLR%20Seventh%20Printing.pdf
# (Chapter 1 - Introduction and Chapter 2 - Statistical Learning)
#
# __A First Course in Linear Algebra__ - http://linear.ups.edu/download/fcla-3.50-tablet.pdf
# (Primarily "Chapter SLE"  on Systems of Linear Equations but also Vectors and Matrices )
#
# __Think Bayes__ - http://www.greenteapress.com/thinkbayes/thinkbayes.pdf
# (Chapter 1 on Baye's Theorem)
#
# ### Not mandatory but good to have:
#
# __Think Python - How To Think Like A Computer Scientist__ - http://greenteapress.com/thinkpython2/thinkpython2.pdf
#
# __Foundations of Data Science__ - https://www.cs.cornell.edu/jeh/book.pdf

# %% [markdown]
# ### Note on axis:
# <div>
# <img src="attachment:dd78bff6-8b23-4c12-8b59-6f68b354b77c.png" width=600)/>
# </div>
