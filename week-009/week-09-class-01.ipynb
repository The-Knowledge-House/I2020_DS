# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 9 - Class 1 - 11/09</h1>
# </div>
#
# ## Objectives for this week:
# * Setting up a Flask Project
# * Creating template/static folders
# * Setting up config Files
# * Serving HTML with Flask
#
#
# ## Today's agenda:
# * Setting up a Flask Project

# %% [markdown]
# # Homework Presentations

# %% [markdown]
# ## `import requests`
#
# `requests.get(url)` - sends a GET request to url.
# `requests.post(url, data=None, json=None)` - sends a POST request to url.
# `requests.patch(url, data=None, json=None)` - sends a PATCH request to url.
# `requests.put(url, data=None, json=None)` - sends a PUT request to url.
#
# `requests.sessions.Session()` - returns Sessions object for context-management

# %% [markdown]
# ## `resp = requests.get("http://www.httpbin.org")`
# ## `resp = requests.Response()`
#
# `resp.apparent_encoding` 	Returns the apparent encoding
# `resp.close()` 	Closes the connection to the server
# `resp.content` 	Returns the content of the response, in bytes
# `resp.cookies` 	Returns a CookieJar object with the cookies sent back from the server
# `resp.elapsed` 	Returns a timedelta object with the time elapsed from sending the request to the arrival of the response
# `resp.encoding` 	Returns the encoding used to decode r.text
# `resp.headers` 	Returns a dictionary of response headers
# `resp.history` 	Returns a list of response objects holding the history of request (url)
# `resp.is_permanent_redirect` 	Returns True if the response is the permanent redirected url, otherwise False
# `resp.is_redirect` 	Returns True if the response was redirected, otherwise False
# `resp.iter_content()` 	Iterates over the response
# `resp.iter_lines()` 	Iterates over the lines of the response
# `resp.json()` 	Returns a JSON object of the result (if the result was written in JSON format, if not it raises an error)
# `resp.links` 	Returns the header links
# `resp.next` 	Returns a PreparedRequest object for the next request in a redirection
# `resp.ok` 	Returns True if status_code is less than 400, otherwise False
# `resp.raise_for_status()` 	If an error occur, this method returns a HTTPError object
# `resp.reason` 	Returns a text corresponding to the status code
# `resp.request` 	Returns the request object that requested this response
# `resp.status_code` 	Returns a number that indicates the status (200 is OK, 404 is Not Found)
# `resp.text` 	Returns the content of the response, in unicode
# `resp.url` 	Returns the URL of the response

# %% [markdown]
# ## `soup = BeautifulSoup(resp.content)`
#
#
# `soup.append(PageElement)` - Appends the given PageElement to the contents of this one.
# `soup.attrs` - Returns a dictionary of attrs.
# `soup.children` - Returns children.
# `soup.clear(decompose=True` - Wipe out all children of this PageElement by calling extract() on them.
# `soup.contents` - Returns list of the contents.
# `soup.decode(pretty_print=False)` - Returns a string or Unicode representation of the parse tree as an HTML or XML document.
# `soup.decompose` - Recursively destroys this PageElement and its children.
# `soup.decomposed` - Returns True when the PageElement has been destroyed, False otherwise.
# `soup.descendants` - Returns descendants.
# `soup.encode` - Render a bytestring representation of this PageElement and its contents.
# `soup.extend([PageElement])` - Appends the given list of PageElements to this one's contents.
# `soup.extract` - Destructively rips this element out of the tree.
# `soup.fetchNextSiblings(attrs, text, limit, attrs_kwargs)` - Find all siblings of this PageElement that match the given criteria and appear later in the document.
# `soup.fetchParents(attrs, text, limit, attrs_kwargs)` - Find all parents of this PageElement that match the given criteria.
# `soup.fetchPrevious(attrs, text, limit, attrs_kwargs)` - Look backwards in the document from this PageElement and find all PageElements that match the given criteria.
# `soup.fetchPreviousSiblings(attrs, text, limit, attrs_kwargs)` - Returns all siblings to this PageElement that match the given criteria and appear earlier in the document.
# `soup.find(name, attrs, recursive=False, limit=None, attrs_kwargs)` -Look in the children of this PageElement and find the first PageElement that matches the given criteria.
# `soup.findAll(name, attrs, recursive=False, limit=None, attrs_kwargs)` - Look in the children of this PageElement and find all PageElements that match the given criteria.
# `soup.findAllNext(name, attrs, text, limit=None, attrs_kwargs)` - Find all PageElements that match the given criteria and appear later in the document than this PageElement.
# `soup.findAllPrevious(name, attrs, text, limit=None, attrs_kwargs)` - Look backwards in the document from this PageElement and find all PageElements that match the given criteria.
# `soup.findChild(name, attrs, text, limit=None, attrs_kwargs)` - Look in the children of this PageElement and find the first PageElement that matches the given criteria.
# `soup.findChildren` - Look in the children of this PageElement and find all PageElements that match the given criteria.
# `soup.findNext` - Find the first PageElement that matches the given criteria and appears later in the document than this PageElement.
# `soup.findNextSibling` - Find the closest sibling to this PageElement that matches the  given criteria and appears later in the document.
# `soup.findNextSiblings` - Find all siblings of this PageElement that match the given criteria and appear later in the document.
# `soup.findParent` - Find the closest parent of this PageElement that matches the given criteria.
# `soup.findParents` - Find all parents of this PageElement that match the given criteria.
# `soup.findPrevious` - Look backwards in the document from this PageElement and find the first PageElement that matches the given criteria.
# `soup.findPreviousSibling` - Returns the closest sibling to this PageElement that matches the given criteria and appears earlier in the document.
# `soup.findPreviousSiblings` - Returns all siblings to this PageElement that match the given criteria and appear earlier in the document.
# `soup.find_all` - Look in the children of this PageElement and find all PageElements that match the given criteria.
# `soup.find_all_next` - Find all PageElements that match the given criteria and appear later in the document than this PageElement.
# `soup.find_all_previous` - Look backwards in the document from this PageElement and find all PageElements that match the given criteria.
# `soup.find_next` - Find the first PageElement that matches the given criteria and appears later in the document than this PageElement.
# `soup.find_next_sibling` - Find the closest sibling to this PageElement that matches the given criteria and appears later in the document.
# `soup.find_next_siblings` - Find all siblings of this PageElement that match the given criteria and appear later in the document.
# `soup.find_parent` -Find the closest parent of this PageElement that matches the given criteria.
# `soup.find_parents` - Find all parents of this PageElement that match the given criteria.
# `soup.find_previous` -Look backwards in the document from this PageElement and find the first PageElement that matches the given criteria.
# `soup.find_previous_sibling` - Returns the closest sibling to this PageElement that matches the given criteria and appears earlier in the document.
# `soup.find_previous_siblings` - Returns all siblings to this PageElement that match the given criteria and appear earlier in the document.
# `soup.get(key, default=None)` - Returns the value of the 'key' attribute for the tag or default.
# `soup.getText` - Get all child strings, concatenated using the given separator.
# `soup.get_attribute_list` -The same as get(), but always returns a list.
# `soup.get_text` - Get all child strings, concatenated using the given separator.
# `soup.has_attr` - Does this PageElement have an attribute with the given name.
# `soup.html` - Represents an HTML or XML tag that is part of a parse tree
# `soup.index` - Find the index of a child by identity, not value.
# `soup.insert` - Insert a new PageElement in the list of this PageElement's children.
# `soup.is_empty_element` - Returns True if element is empty.
# `soup.new_string` Create a new NavigableString object associated with this BeautifulSoup object.
# `soup.new_tag` - Return new Tag object associated with this BeautifulSoup object.
# `soup.next` - Returns next.
# `soup.nextGenerator` - Returns generator of next.
# `soup.nextSibling` - Returns next sibling.
# `soup.nextSiblingGenerator` - Returns generator of next siblings.
# `soup.next_element` - Returns next element.
# `soup.next_elements` - Returns generator of next elements.
# `soup.next_sibling` - Returns next sibling.
# `soup.next_siblings` - Returns generator of next siblings.
# `soup.parent` - Returns parent.
# `soup.parentGenerator` - Returns generator of parents.
# `soup.parents` - Returns generator of parents.
# `soup.prettify` - Returns this PageElement as a string.
# `soup.previous` - Returns previous.
# `soup.previousGenerator` - Returns generator of previous.
# `soup.previousSibling` - Returns previous sibling.
# `soup.previousSiblingGenerator` - Returns generator of previous siblings.
# `soup.previous_element` - Returns previous element.
# `soup.previous_elements` - Returns generator of previous elements.
# `soup.previous_sibling` - Returns previous sibling.
# `soup.previous_siblings` - Returns generator of previous siblings.
# `soup.replaceWith(PageElement)` - Replace this PageElement with another one, keeping the rest of the tree the same.
# `soup.replaceWithChildren` - Replace this PageElement with its contents.
# `soup.replace_with(PageElement)` - Replace this PageElement with another one, keeping the rest of the tree the same.
# `soup.replace_with_children` - Replace this PageElement with its contents.
# `soup.reset` - Reset this object to a state as though it had never parsed any
# `soup.select` - select by CSS tag.
# `soup.select_one` -Perform a CSS selection operation on the current element.
# `soup.smooth` - Smooth out this element's children by consolidating consecutive strings.
# `soup.string` - Returns a NavigableString of PageElements inner text.
# `soup.strings` - Returns generator of the strings (including newlines).
# `soup.stripped_strings` - Returns generator of stripped strings (no newlines - preferable).
# `soup.text` - Returns the str of the PageElement.
# `soup.unwrap` - Replace this PageElement with its contents.
# `soup.wrap` - Wrap this PageElement inside another one.
#
#
#         All find_* methods take a common set of arguments. See the online
#         documentation for detailed explanations.
#
#         :param name: A filter on tag name.
#         :param attrs: A dictionary of filters on attribute values.
#         :param text: A filter for a NavigableString with specific text.
#         :kwargs: A dictionary of filters on attribute values.
#         :return: A PageElement.
#         :rtype: bs4.element.Tag | bs4.element.NavigableString

# %%
import requests

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup('<h1 class="headline">Hello World</h1>')

tag = soup.find('h1')
print(soup)
print(type(soup))
print(type(tag))

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup('<h1 class="headline">Hello World</h1>')

text = soup.string
print(soup)
print(type(soup))
print(type(text))
print(text)

# %%
import requests

from bs4 import BeautifulSoup, SoupStrainer

resp = requests.get('https://www.theknowledgehouse.org')


strainer = SoupStrainer("a")
soup = BeautifulSoup(resp.content, parse_only=strainer)
soup

# %% [markdown]
# # Web development
#
# How does the web work?
#
# TCP/IP: Transmission Control Protocol and Internet Protocol are communication protocols that define how data should travel across the internet. This is like the transport mechanisms that let you place an order, go to the shop, and buy your goods. In our example, this is like a car or a bike (or however else you might get around).
# ![image.png](attachment:a54a9ace-7ff5-4ef3-8e9a-2f7d8d917eba.png)
#
# DNS: Domain Name Servers are like an address book for websites. When you type a web address in your browser, the browser looks at the DNS to find the website's real address before it can retrieve the website. The browser needs to find out which server the website lives on, so it can send HTTP messages to the right place (see below). This is like looking up the address of the shop so you can access it.
# ![image.png](attachment:f6f3f8e8-ff48-40ee-9add-d7eb52583a75.png)
#
# HTTP: Hypertext Transfer Protocol is an application protocol that defines a language for clients and servers to speak to each other. This is like the language you use to order your goods.
# ![image.png](attachment:a6b32e5d-ac8d-47a1-b1cb-fb381d0f80a1.png)
#
# Component files: A website is made up of many different files, which are like the different parts of the goods you buy from the shop. These files come in two main types:
# * Code files: Websites are built primarily from HTML, CSS, and JavaScript, though you'll meet other technologies a bit later.
# * Assets: This is a collective name for all the other stuff that makes up a website, such as images, music, video, Word documents, and PDFs.
#
# So what happens, exactly?
#
# When you type a web address into your browser (for our analogy that's like walking to the shop):
#
# 1. The browser goes to the DNS server, and finds the real address of the server that the website lives on (you find the address of the shop).
# 2. The browser sends an HTTP request message to the server, asking it to send a copy of the website to the client (you go to the shop and order your goods). This message, and all other data sent between the client and the server, is sent across your internet connection using TCP/IP.
# 3. If the server approves the client's request, the server sends the client a "200 OK" message, which means "Of course you can look at that website! Here it is", and then starts sending the website's files to the browser as a series of small chunks called data packets (the shop gives you your goods, and you bring them back to your house).
# 4. The browser assembles the small chunks into a complete web page and displays it to you (the goods arrive at your door — new shiny stuff, awesome!).
#
# [source](https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web/How_the_Web_works)

# %% [markdown]
# # Client side Web Development
#
# ![image.png](attachment:a9f7be12-b47e-4892-925d-3101fe43c547.png)

# %% [markdown]
# # "Server Side" or Backend Web Development
#
# ![image.png](attachment:bc6e3a3f-73a1-42b0-83a1-b6f796c05a70.png)
#
# ![image.png](attachment:de2da8b5-d699-4860-8f7f-e7b9829708aa.png)

# %% [markdown]
# # MVC applications
#
# ![image.png](attachment:b00768b9-05f6-4624-bc6a-4ddf40b92ac6.png)

# %% [markdown]
# # Flask
#
# ![image.png](attachment:67a82bf2-c7ac-4bca-a067-00999aa14cf6.png)
#
# Flask is a microframework for web applications in Python. It is bare bones and requires that you provide additional functionality. However, it's minimalism means it's one of the quickest to get started with.
#
# https://flask.palletsprojects.com/en/1.1.x/
#
# https://github.com/pallets/flask/

# %%
# !pip install Flask

# %%
# first you need to import of course
from flask import Flask

# create an instance of the Flask class
app = Flask(__name__)

# secret key needs to be set to something really secret:
app.config['SECRET_KEY'] = b'\xf6U\xb5\xfb\x0c\x17\xca\xd0\xb7|\xe6S\xe0\xa7\xfb\xce \xcd\xd9\xc7#K\xb0Y'

@app.route('/')
def home():
    return render_template('home.html')

@app.route('/about')
def about():
    return render_template('about.html')

@app.route('/user/<username>')
def show_user(username):
    return render_template('user.html', user=username)

@app.route('/post/<int:post_id>')
def show_post(post_id):
    return render_template('post.html', post_id=post_id)

@app.route('/path/<path:subpath>')
def show_subpath(subpath):
    return render_template('path.html', path=subpath)

app.run(debug=True)

# %%
# note: use the following code to generate secret keys:

import os

os.urandom(24)

# %%
# code to see full config
[f"{k}: {v}" for k,v in app.config.items()]

# %% [markdown]
# # Templating with Jinja
#
# `Flask` uses `Jinja` for templating.
#
# https://palletsprojects.com/p/jinja/

# %%
import socket
import threading

from flask import Flask
from werkzeug.serving import run_simple

app = Flask('webapp')

@app.route('/')
def home():
    return "hello world"

def _init_port() -> int:
    """Creates a random free port."""
    # see https://stackoverflow.com/a/5089963/2297345
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.bind(('localhost', 0))

    port = sock.getsockname()[1]
    sock.close()
    return int(port)

def _start_server() -> None:
    """Starts a flask server in the background."""
    _port = _init_port()
    thread = threading.Thread(target=lambda: run_simple('localhost', _port, app))
    thread.start()

# %%
_start_server()

# %%
import requests

resp = requests.get("http://localhost:59593")
print(resp.text)
