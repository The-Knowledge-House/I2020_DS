# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1 >Week 24 Class 3 03/10</h1>
# </div>
#
# ## Objectives for this week:
# * Reviewing concepts we've covered
#
# ## Todays Agenda
# * Visualization Code Along

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Homework Presentations</h1>
# </div>

# %% [markdown]
# # Exercise 3

# %% [markdown]
# On a $2D$ plane, there are $n$ points with integer coordinates `points[i] = [xi, yi]`. Return the minimum time in seconds to visit all the points in the order given by points.
#
# You can move according to these rules:
# * In 1 second, you can either:
#   - move vertically by one unit,
#   - move horizontally by one unit, or
#   - move diagonally sqrt(2) units (in other words, move one unit vertically then one unit horizontally in 1 second).
# * You have to visit the points in the same order as they appear in the array.
# * You are allowed to pass through points that appear later in the order, but these do not count as visits.
#
#
#
# **Example 1:**
#
# ![1626_example_1.PNG](attachment:7dad9a8c-31ed-4db5-b8aa-d7ae4d231237.PNG)
#
# **Input:** `points = [[1,1],[3,4],[-1,0]]`
# **Output:** 7
# **Explanation:**
# One optimal path is `[1,1]` -> `[2,2]` -> `[3,3]` -> `[3,4]` -> `[2,3]` -> `[1,2]` -> `[0,1]` -> `[-1,0]`
# Time from `[1,1]` to `[3,4]` = 3 seconds
# Time from `[3,4]` to `[-1,0]` = 4 seconds
# Total time = 7 seconds
#
# **Example 2:**
#
# **Input:** points = `[[3,2],[-2,2]]`
# **Output:** 5
#
#
#
# **Constraints:**
# * `points.length == n`
# * `1 <= n <= 100`
# * `points[i].length == 2`
# * `-1000 <= points[i][0], points[i][1] <= 1000`
#
#
# **Hint:**
# To get from `[0,0]` to `[3,4]` you must move 3 unit along the x-coordinate and 4 units along the y-coordinate. Remember that, in 1 second, you can move diagonally to 1 unit on the x-coordinate and 1 unit on  the y-coordinate. For `[0,0]` and `[3,4]`, that means in 3 seconds you can get to `[3,3]` but you will have to expend 1 second to get from `[3,3]` to `[3,4]`. Think about this.

# %%
def exercise3(points: List[List[int]]) -> int:
    x, y = points[0][0], points[0][1]
    times = []
    for point in points[1:]:
        x_diff = abs(point[0]-x)
        y_diff = abs(point[1]-y)
        times.append(max(x_diff, y_diff))
        x,y = point[0], point[1]
    return sum(times)

# %%
from typing import List

def exercise3(points: List[List[int]]) -> int:
    # let's store the first two x,y values into 
    # our placehold variables for each point.
    x, y = points[0][0], points[0][1]
    # let's create a list to hold our times 
    # so we can sum them at the end to get total time
    times = []
    for point in points[1:]:
        # let's calculate the distance we
        # need to travel along the x-axis
        x_diff = abs(point[0]-x)
        # let's calculate the distance we
        # need to travel along the y-axis
        y_diff = abs(point[1]-y)
        # the time spent traveling will be 
        # the max of the two distances
        times.append(max(x_diff, y_diff))
        # updating our points placeholders for the
        # next loop
        x,y = point[0], point[1]
    # return the sum of the times to get the total
    return sum(times)

# %%
exercise3([[1,1],[3,4],[-1,0]])

# %%
exercise3([[3,2],[-2,2]])

# %%
import unittest

class Exercise3TestCase(unittest.TestCase):
    def test(self):
        args = (
            ([[1,1],[3,4],[-1,0]], 7), ([[55,-492],[-801,-52],[-799,-294],[707,-165],[32,-132],[-310,-998],[618,-212],[13,467],[-957,-290],[-6,-411],[821,940],[-193,-391],[-767,492],[337,220],[290,-179],[672,-865],[158,-170],[38,-629],[445,727],[871,363],[115,637],[63,-267],[488,-732],[352,9],[618,79],[-845,-665],[34,-566],[-736,-744],[-159,222],[-368,-290],[-452,-812],[510,-306],[989,925],[-583,524],[285,-337],[-668,782],[-377,-724],[768,20],[256,-997],[-37,-359],[997,-183],[-68,353],[-57,971],[-84,-813],[199,-479],[-869,914],[220,-924],[-926,29],[-377,853],[330,-884],[741,-766],[-9,-951],[419,-413],[-873,336],[760,951]], 51062),
            ([[3,2],[-2,2]], 5), ([[559,511],[932,618],[-623,-443],[431,91],[838,-127],[773,-917],[-500,-910],[830,-417],[-870,73],[-864,-600],[450,535],[-479,-370],[856,573],[-549,369],[529,-462],[-839,-856],[-515,-447],[652,197],[-83,345],[-69,423],[310,-737],[78,-201],[443,958],[-311,988],[-477,30],[-376,-153],[-272,451],[322,-125],[-114,-214],[495,33],[371,-533],[-393,-224],[-405,-633],[-693,297],[504,210],[-427,-231],[315,27],[991,322],[811,-746],[252,373],[-737,-867],[-137,130],[507,380],[100,-638],[-296,700],[341,671],[-944,982],[937,-440],[40,-929],[-334,60],[-722,-92],[-35,-852],[25,-495],[185,671],[149,-452]], 49088),
        )
        for arg, ret in args:
            with self.subTest(arg=arg, ret=ret):
                self.assertEqual(exercise3(arg), ret)

unittest.main(argv=[''], verbosity=0, exit=False)

# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#             padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Visualizations Code Along</h1>
# </div>

# %% [markdown]
# **Here's a helpful guide to when to use various types of charts.**
#
# ![w null_wnzyb35elts31.jpg](attachment:a264dd6c-0f53-4a86-a4ae-ca76933bcbf3.jpg)

# %% [markdown]
# # Let's start with some simple ones.

# %%
# line chart

data = np.arange(100)
data *= -40


fig, ax = plt.subplots()
ax.set_xlabel('the more I talk about math')
ax.set_ylabel('how much students understand')
ax.set(title='Teaching')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
ax.plot(data)
plt.show()

# %%
# bar chart

# %%
df = pd.read_csv('../datasets/grades.csv')
df.head()

# %%
df.groupby('gender')['math score'].mean()

# %%
male_scores = df[df['gender']=='male'][['reading score', 'writing score', 'math score']].mean()

# %%
female_scores = df[df['gender']=='female'][['reading score', 'writing score', 'math score']].mean()

# %%
labels = ['reading', 'writing', 'math']
x = np.arange(len(labels))

width = 0.35


fig, ax = plt.subplots(figsize=(8,7))
ax.bar(x - width/2, male_scores, width=width, label='male')
ax.bar(x + width/2, female_scores, width=width, label='female')
plt.show()

# %%
# pie chart

# %%
# scatter plot

# %% [markdown]
# # LAB
