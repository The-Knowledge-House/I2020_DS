# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 11 - Class 3 - 11/24</h1>
# </div>
#
# ## Objectives for this week:

# %% [markdown]
# * RESTful APIs
# * GraphQL APIs
# * Integrating models in views
# * Connecting our database to our API

# %% [markdown]
# Today's objective:
# * Lab Day

# %% [markdown]
# # Exercise
#
# Given a string s and an integer array indices of the same length.
#
# The string s will be shuffled such that the character at the ith position moves to indices[i] in the shuffled string.
#
# Return the shuffled string.
#
# Example 1:
# ![image.png](attachment:48c0fb92-e527-45be-aa2e-235a38b84145.png)
# ```
# Input: s = "codeleet", indices = [4,5,6,7,0,2,1,3]
# Output: "leetcode"
# Explanation: As shown, "codeleet" becomes "leetcode" after shuffling.
# ```
#
# Example 2:
# ```
# Input: s = "abc", indices = [0,1,2]
# Output: "abc"
# Explanation: After shuffling, each character remains in its position.
# ```
# Example 3:
# ```
# Input: s = "aiohn", indices = [3,1,4,2,0]
# Output: "nihao"
# ```
# Example 4:
# ```
# Input: s = "aaiougrt", indices = [4,0,2,6,7,3,1,5]
# Output: "arigatou"
# ```
# Example 5:
# ```
# Input: s = "art", indices = [1,0,2]
# Output: "rat"
#
# ```

# %%
def func(string, indices):
    return string, indices

try:
    assert(func("codeleet", [4,5,6,7,0,2,1,3]) == "leetcode")
    assert(func("abc",[0,1,2]) == "abc")
    assert(func("aiohn",[3,1,4,2,0]) == "nihao")
    assert(func("aaiougrt",[4,0,2,6,7,3,1,5]) == "arigatou")
    assert(func("art",[1,0,2]) == "rat")
    print("solution is correct")
except:
    print("solution is incorrect")
# Out:
# solution is incorrect

# %% [markdown]
# # Some resources for your project

# %% [markdown]
# ### Requests
#
# docs: https://requests.readthedocs.io/en/master/user/quickstart/
#
# using requests: https://www.pythonforbeginners.com/requests/using-requests-in-python
#
# realpython article: https://realpython.com/python-requests/
#
# w3schools reference: https://www.w3schools.com/python/module_requests.asp
#
# ### BeautifulSoup
#
# docs: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# cheatsheet: http://akul.me/blog/2016/beautifulsoup-cheatsheet/
#
# guide: https://blog.hartleybrody.com/web-scraping-cheat-sheet/
#
# article: https://www.pythonforbeginners.com/python-on-the-web/web-scraping-with-beautifulsoup
#
#
# ### Flask
#
# flask cheatsheet: https://s3.us-east-2.amazonaws.com/prettyprinted/flask_cheatsheet.pdf
#
# docs: https://flask.palletsprojects.com/en/1.1.x/
#
# minimal application: https://flask.palletsprojects.com/en/1.1.x/quickstart/#a-minimal-application
#
# routing/views: https://flask.palletsprojects.com/en/1.1.x/quickstart/#routing
#
# templates: https://flask.palletsprojects.com/en/1.1.x/quickstart/#rendering-templates
#
# more on templating: https://jinja.palletsprojects.com/en/2.11.x/
#
# ### Flask-SQLAlchemy
#
# docs: https://flask-sqlalchemy.palletsprojects.com/en/2.x/
#
# minimal application: https://flask-sqlalchemy.palletsprojects.com/en/2.x/quickstart/#a-minimal-application
#
# simple models: https://flask-sqlalchemy.palletsprojects.com/en/2.x/models/#simple-example
#
# queries: https://flask-sqlalchemy.palletsprojects.com/en/2.x/queries/
#
# Flask-SQLAlchemy (with examples) https://pythonbasics.org/flask-sqlalchemy/
#
# Getting started tutorial: https://medium.com/@RG2021/flask-with-sqlalchemy-database-39fc0959609c
